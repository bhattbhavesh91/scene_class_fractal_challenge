# %%
import cv2
import numpy as np
import os
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from random import shuffle
import tensornets as nets
from PIL import Image
# %matplotlib inline

# %%
os.listdir('hackthon-data/ai_challenger_scene_train/')
# Out:
# ['scene_classes.csv', 'scene_train_images', 'scene_labels.csv']

# %%
df_a = pd.read_csv('hackthon-data/ai_challenger_scene_train/scene_labels.csv')

# %%
df_a.shape
# Out:
# (53879, 3)

# %%
df_a = df_a.loc[df_a.label_id != 'jsessionid=1B3094C4FF247D0E497F91743433395E?r='].reset_index()

# %%
len(df_a.label_id.unique())
# Out:
# 81

# %%
df_a.label_id = df_a.label_id.astype(int)
df_a.drop(['index', 'Unnamed: 0'], axis=1, inplace=True)

# %%
df_a.head()
# Out:
#                                        image_id  label_id
# 0  79f993ae0858ae238b22968c5934d1ddba585ae4.jpg        66
# 1  e963208fe9e90df0c385f7367bcdb6d0d5d0b165.jpg        61
# 2  02df5ecbf7c749ccc9d833f129bbd5d9837940ce.jpg        64
# 3  5620eb385b7567fb087813cf5233b5ceecdeeca3.jpg        31
# 4  f8b4d42001a562fc63b9b39c02531661c0e236ca.jpg        19

# %%
df_b = pd.read_csv('hackthon-data/ai_challenger_scene_train/scene_classes.csv', header=None)
df_b.drop(1, axis=1, inplace=True)
df_b.rename({0:'label_id', 2: 'label_name'}, axis=1, inplace=True)

# %%
df_b.head()
# Out:
#    label_id        label_name
# 0         0  airport_terminal
# 1         1     landing_field
# 2         2    airplane_cabin
# 3         3    amusement_park
# 4         4      skating_rink

# %%
df = pd.merge(df_a, df_b, on='label_id', how='inner')

# %%
df.head()
# Out:
#                                        image_id  label_id     label_name
# 0  79f993ae0858ae238b22968c5934d1ddba585ae4.jpg        66  auto_showroom
# 1  a74b20339e92d39e00920806f1aa6a3813d9481d.jpg        66  auto_showroom
# 2  dc389691f5cd2233f1bda34940017b33ff386298.jpg        66  auto_showroom
# 3  3584d24e091c6f3d79fa1d40f80f2789fac73b46.jpg        66  auto_showroom
# 4  2a27398da703ac3212858b7f9c442258203ffd8f.jpg        66  auto_showroom

# %%
set(df.label_name)
# Out:
# {'airplane_cabin',
#  'airport_terminal',
#  'amusement_park',
#  'aquarium',
#  'aqueduct',
#  'arena/performance',
#  'art_room',
#  'assembly_line',
#  'athletic_field',
#  'auto_showroom',
#  'balcony',
#  'banquet_hall',
#  'bar',
#  'baseball_field',
#  'basketball_court',
#  'bazaar',
#  'beauty_salon',
#  'bedchamber',
#  'bowling_alley',
#  'boxing_ring',
#  'bridge',
#  'campsite',
#  'church',
#  'classroom',
#  'clothing_store',
#  'coffee_shop',
#  'conference_room',
#  'construction_site',
#  'countryside',
#  'desert/sand',
#  'dining_room',
#  'discotheque',
#  'elevator/staircase',
#  'farm/farm_field',
#  'firefighting',
#  'football_field',
#  'forest',
#  'garden',
#  'gas_station',
#  'general_store',
#  'golf_course',
#  'greenhouse',
#  'gymnasium',
#  'hospital',
#  'igloo/ice_engraving',
#  'kitchen',
#  'laboratory',
#  'lake/river',
#  'landfill',
#  'landing_field',
#  'lawn',
#  'library/bookstore',
#  'mountain',
#  'museum',
#  'music_studio',
#  'nursery',
#  'ocean/beach',
#  'office',
#  'orchard/vegetable',
#  'palace',
#  'pasture',
#  'pavilion',
#  'plaza',
#  'racecourse',
#  'raft',
#  'recreation_room',
#  'repair_shop',
#  'residential_neighborhood',
#  'rodeo',
#  'skating_rink',
#  'ski_slope',
#  'soccer_field',
#  'station/platform',
#  'street',
#  'swimming_pool',
#  'television_studio',
#  'temple/east_asia',
#  'ticket_booth',
#  'tower',
#  'volleyball_court'}

# %%
df.loc[df.label_name == 'airport_terminal', :].head()
# Out:
#                                            image_id  label_id  \
# 16480  6170cbea8b54c3aac36b3448135a2265a502d6a1.jpg         0
# 16481  4da9ecb7c74d6170e6ac6ce20c7cc5a586f9485a.jpg         0
# 16482  0281566764968f1527b459bbda402ecf9e20ec40.jpg         0
# 16483  544c182febc40b01dce005b760b8dbd291fee718.jpg         0
# 16484  f2e160fdfbc3fc716b12629640b02e47f24d8889.jpg         0
#
#              label_name
# 16480  airport_terminal
# 16481  airport_terminal
# 16482  airport_terminal
# 16483  airport_terminal
# 16484  airport_terminal

# %%
img1 = mpimg.imread('hackthon-data/ai_challenger_scene_train/scene_train_images/6170cbea8b54c3aac36b3448135a2265a502d6a1.jpg')
imgplot = plt.imshow(img1)
plt.show()

# %%
img = mpimg.imread('hackthon-data/ai_challenger_scene_train/scene_train_images/3584d24e091c6f3d79fa1d40f80f2789fac73b46.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
def indices_to_one_hot(data, nb_classes):
    """
    Convert an iterable of indices to one-hot encoded labels.
    """
    targets = np.array(data).reshape(-1)
    return np.eye(nb_classes)[targets]

# %%
ROOT_PATH = "hackthon-data/ai_challenger_scene_train/scene_train_images/"

# %%
df.head()
# Out:
#                                        image_id  label_id     label_name
# 0  79f993ae0858ae238b22968c5934d1ddba585ae4.jpg        66  auto_showroom
# 1  a74b20339e92d39e00920806f1aa6a3813d9481d.jpg        66  auto_showroom
# 2  dc389691f5cd2233f1bda34940017b33ff386298.jpg        66  auto_showroom
# 3  3584d24e091c6f3d79fa1d40f80f2789fac73b46.jpg        66  auto_showroom
# 4  2a27398da703ac3212858b7f9c442258203ffd8f.jpg        66  auto_showroom

# %%
def next_batch(num, data, labels):
    '''
    Return a total of num random samples and labels. 
    '''
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle), np.asarray(labels_shuffle)

# %%
label = []
images = []
for index, row in df.iterrows():
    label.append(indices_to_one_hot(row['label_id'], 80))
    images.append(cv2.imread(ROOT_PATH + row['image_id']))

# %%
images_array = np.array(images)
labels_array = np.array(label)

# %%
# np.save('make_checkpoint_folders/images_array.npy', images_array)
# np.save('make_checkpoint_folders/labels_array.npy', labels_array)

# %%
labels_array = labels_array.reshape(53876, 80)

# %%
learning_rate = 0.002
num_steps = 88000
batch_size = 16
display_step = 1
dropout = 0.30
# dropout = 0.75

keep_prob = tf.placeholder(tf.float32)

# %%
x = tf.placeholder(tf.float32, shape=(None, 224, 224, 3), name='input_x')
y = tf.placeholder(tf.float32, shape=(None, 80), name='output_y')

# %%
logits = nets.VGG19(x, is_training=True, classes=80)
model = tf.identity(logits, name='logits')

loss_op = tf.losses.softmax_cross_entropy(y, logits)
train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss_op)

correct_pred = tf.equal(tf.argmax(model, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %%
# logits.print_outputs()

# %%
# logits.print_summary()

# %%
# init = tf.global_variables_initializer()
# with tf.Session() as sess:
#     # Run the initializer
#     sess.run(init)
#     for step in range(1, num_steps+1):
#         batch_x, batch_y = next_batch(batch_size,images_array,labels_array)
#         # Run optimization op (backprop)
#         sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: 1.0})
#         if step % display_step == 0 or step == 1:
#             # Calculate batch loss and accuracy
#             loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,Y: batch_y,keep_prob: dropout})
#             print("Step " + str(step) + ", Minibatch Loss= " + \
#                   "{:.4f}".format(loss) + ", Training Accuracy= " + \
#                   "{:.3f}".format(acc))

#     print("Optimization Finished!")

# %%
save_model_path = './make_checkpoint_folders1'
saver = tf.train.Saver(max_to_keep=3)
print('Training...')
with tf.Session() as sess:
    ckpt = tf.train.get_checkpoint_state(save_model_path)
    # Initializing the variables
    if ckpt and ckpt.model_checkpoint_path:
        print('Restore the model from checkpoint {}.'.format(ckpt.model_checkpoint_path))
        start_step = int(ckpt.model_checkpoint_path.split('/')[-1].split('-')[-1])
        saver.restore(sess, ckpt.model_checkpoint_path)
        print (start_step)
    else:
        sess.run(tf.global_variables_initializer())
        start_step = 0
        print('Start training from new start.')        
        print('global_variables_initializer ... done ...')
        sess.run(logits.pretrained())
        print('model.pretrained ... done ... ')

    # Training cycle
    print('starting training ... ')
    for step in range(start_step, num_steps+1):
        batch_x, batch_y = next_batch(batch_size,images_array,labels_array)
        # Run optimization op (backprop)
        sess.run(train, feed_dict={x: batch_x, y: batch_y, keep_prob: 0.5})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={x: batch_x,y: batch_y,keep_prob: dropout})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))
        if step % 25 == 0:
            saver.save(sess, "make_checkpoint_folders/model.ckpt", global_step=step)
    print("Optimization Finished!")
    saver.save(sess, "final-model.ckpt", global_step=step)
# Out:
# Training...
# Start training from new start.
# global_variables_initializer ... done ...
# model.pretrained ... done ...
# starting training ...
# Step 0, Minibatch Loss= 4.2783, Training Accuracy= 0.125
# Step 1, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 2, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 3, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 4, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 5, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 6, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 7, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 8, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 9, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 11, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 12, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 13, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 14, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 15, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 16, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 17, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 18, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 19, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 21, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 22, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 23, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 24, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 25, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 26, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 27, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 28, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 29, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 30, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 31, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 32, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 33, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 34, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 35, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 36, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 37, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 38, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 39, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 40, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 41, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 42, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 43, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 44, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 45, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 46, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 47, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 48, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 49, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 50, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 51, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 52, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 53, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 54, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 55, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 56, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 57, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 58, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 59, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 60, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 61, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 62, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 63, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 64, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 65, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 66, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 67, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 68, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 69, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 70, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 71, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 72, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 73, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 74, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 75, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 76, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 77, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 78, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 79, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 80, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 81, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 82, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 83, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 84, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 85, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 86, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 87, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 88, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 89, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 90, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 91, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 92, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 93, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 94, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 95, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 96, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 97, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 98, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 99, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 100, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 101, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 102, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 103, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 104, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 105, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 106, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 107, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 108, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 109, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 110, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 111, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 112, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 113, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 114, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 115, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 116, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 117, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 118, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 119, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 120, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 121, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 122, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 123, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 124, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 125, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 126, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 127, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 128, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 129, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 131, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 132, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 133, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 134, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 135, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 136, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 137, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 138, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 139, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 140, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 141, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 142, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 143, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 144, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 145, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 146, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 147, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 148, Minibatch Loss= 4.2783, Training Accuracy= 0.125
# Step 149, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 150, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 151, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 152, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 153, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 154, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 155, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 156, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 157, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 158, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 159, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 160, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 161, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 162, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 163, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 164, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 165, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 166, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 167, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 168, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 169, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 170, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 171, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 172, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 173, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 174, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 175, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 176, Minibatch Loss= 4.2783, Training Accuracy= 0.125
# Step 177, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 178, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 179, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 180, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 181, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 182, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 183, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 184, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 185, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 186, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 187, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 188, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 189, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 190, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 191, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 192, Minibatch Loss= 4.2783, Training Accuracy= 0.125
# Step 193, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 194, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 195, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 196, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 197, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 198, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 199, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 200, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 201, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 202, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 203, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 204, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 205, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 206, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 207, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 208, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 209, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 210, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 211, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 212, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 213, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 214, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 215, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 216, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 217, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 218, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 219, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 220, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 221, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 222, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 223, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 224, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 225, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 226, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 227, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 228, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 229, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 230, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 231, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 232, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 233, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 234, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 235, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 236, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 237, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 238, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 239, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 240, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 241, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 242, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 243, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 244, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 245, Minibatch Loss= 4.2783, Training Accuracy= 0.125
# Step 246, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 247, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 248, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 249, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 250, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 251, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 252, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 253, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 254, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 255, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 256, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 257, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 258, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 259, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 260, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 261, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 262, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 263, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 264, Minibatch Loss= 4.3408, Training Accuracy= 0.062
# Step 265, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 266, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 267, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 268, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 269, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 270, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 271, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 272, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 273, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 274, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# Step 275, Minibatch Loss= 4.4033, Training Accuracy= 0.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-824debb99d26> in <module>()
#      29             print("Step " + str(step) + ", Minibatch Loss= " +                   "{:.4f}".format(loss) + ", Training Accuracy= " +                   "{:.3f}".format(acc))
#      30         if step % 25 == 0:
# ---> 31             saver.save(sess, "make_checkpoint_folders/model.ckpt", global_step=step)
#      32     print("Optimization Finished!")
#      33     saver.save(sess, "final-model.ckpt", global_step=step)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1464         with sess.graph.as_default():
#    1465           self.export_meta_graph(
# -> 1466               meta_graph_filename, strip_default_attrs=strip_default_attrs)
#    1467
#    1468     if self._is_empty:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py in export_meta_graph(self, filename, collection_list, as_text, export_scope, clear_devices, clear_extraneous_savers, strip_default_attrs)
#    1509         clear_devices=clear_devices,
#    1510         clear_extraneous_savers=clear_extraneous_savers,
# -> 1511         strip_default_attrs=strip_default_attrs)
#    1512
#    1513   def restore(self, sess, save_path):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py in export_meta_graph(filename, meta_info_def, graph_def, saver_def, collection_list, as_text, graph, export_scope, clear_devices, clear_extraneous_savers, strip_default_attrs, **kwargs)
#    1798       clear_extraneous_savers=clear_extraneous_savers,
#    1799       strip_default_attrs=strip_default_attrs,
# -> 1800       **kwargs)
#    1801   return meta_graph_def
#    1802
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/meta_graph.py in export_scoped_meta_graph(filename, graph_def, graph, export_scope, as_text, unbound_inputs_col_name, clear_devices, saver_def, clear_extraneous_savers, strip_default_attrs, **kwargs)
#    1005         os.path.dirname(filename),
#    1006         os.path.basename(filename),
# -> 1007         as_text=as_text)
#    1008
#    1009   return scoped_meta_graph_def, var_list
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/graph_io.py in write_graph(graph_or_graph_def, logdir, name, as_text)
#      71                                         text_format.MessageToString(graph_def))
#      72   else:
# ---> 73     file_io.atomic_write_string_to_file(path, graph_def.SerializeToString())
#      74   return path
#
# KeyboardInterrupt:
